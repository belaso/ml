# %% [markdown]
# <a href="https://colab.research.google.com/github/belaso/ml/blob/master/Habeck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "pymongo[srv]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 269 kB 5.8 MB/s
# ...

# %%
import pandas as pd
from pymongo import MongoClient
from getpass import getpass
pw = getpass()
client = MongoClient("mongodb+srv://ml:{}@cluster0.tpudyxt.mongodb.net/?retryWrites=true&w=majority".format(pw))
db = client["test"]
cursor = db["habeck"].find({}, projection = {'postUrl':1, 'postDate':1, 'textContent':1, 'likeCount':1, 'commentCount':1}, sort =[('likeCount', -1), ('commentCount', -1)])
df =  pd.DataFrame(list(cursor))
# Out:
# ··········

# %%
pd.set_option('display.max_colwidth', 100)
df
# Out:
#                           _id  \
# 0    630cd201d303b683c02c4ae5
# 1    630cd201d303b683c02c4aff
# 2    630cd201d303b683c02c4ad7
# 3    630cd201d303b683c02c4ade
# 4    630cd201d303b683c02c4adb
# ..                        ...
# 149  630cd201d303b683c02c4b03
# 150  630cd201d303b683c02c4b05
# 151  630cd201d303b683c02c4a79
# 152  630cd201d303b683c02c4a7c
# 153  630cd201d303b683c02c4ad3
#
#                                                                       postUrl  \
# 0    https://www.linkedin.com/feed/update/urn:li:activity:6969767021961961472
# 1    https://www.linkedin.com/feed/update/urn:li:activity:6969681287632568320
# 2    https://www.linkedin.com/feed/update/urn:li:activity:6969871628578996224
# 3    https://www.linkedin.com/feed/update/urn:li:activity:6969816728713277440
# 4    https://www.linkedin.com/feed/update/urn:li:activity:6969848445805215744
# ..                                                                        ...
# ...

# %%
df[df["likeCount"]>=5]
# Out:
#                          _id  \
# 0   630cd201d303b683c02c4ae5
# 1   630cd201d303b683c02c4aff
# 2   630cd201d303b683c02c4ad7
# 3   630cd201d303b683c02c4ade
# 4   630cd201d303b683c02c4adb
# 5   630cd201d303b683c02c4ae8
# 6   630cd201d303b683c02c4aa3
# 7   630cd201d303b683c02c4abb
# 8   630cd201d303b683c02c4aeb
# 9   630cd201d303b683c02c4aa9
# 10  630cd201d303b683c02c4a8c
# 11  630cd201d303b683c02c4aee
# 12  630cd201d303b683c02c4a88
# 13  630cd201d303b683c02c4a94
# 14  630cd201d303b683c02c4abc
# 15  630cd201d303b683c02c4ac1
# 16  630cd201d303b683c02c4a86
# 17  630cd201d303b683c02c4ad8
# 18  630cd201d303b683c02c4abd
# 19  630cd201d303b683c02c4aca
# 20  630cd201d303b683c02c4af5
# 21  630cd201d303b683c02c4aae
# 22  630cd201d303b683c02c4a71
# 23  630cd201d303b683c02c4a8a
# 24  630cd201d303b683c02c4aa8
# 25  630cd201d303b683c02c4ac2
# 26  630cd201d303b683c02c4ac9
# 27  630cd201d303b683c02c4ac6
# 28  630cd201d303b683c02c4aad
# 29  630cd201d303b683c02c4a77
# 30  630cd201d303b683c02c4ab0
# ...

# %%
# !pip install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16367 sha256=47cea451d4c15cdc36e18af8febd8108b9ecbfc99ed7e6ad082c74d0b5a30037
#   Stored in directory: /root/.cache/pip/wheels/0c/be/fe/93a6a40ffe386e16089e44dad9018ebab9dc4cb9eb7eab65ae
# Successfully built googletrans
# ...
#   Attempting uninstall: googletrans
#     Found existing installation: googletrans 3.0.0
#     Uninstalling googletrans-3.0.0:
#       Successfully uninstalled googletrans-3.0.0
# ...

# %%
import googletrans
from googletrans import Translator
translator = Translator()

def translate(text):
  return translator.translate(str(text), dest='de').text

df["textContentTranslated"] = df["textContent"].apply(lambda x : translate(x))
# Out:
# 'Wie geht es dir'

# %%
df
# Out:
#                           _id  \
# 0    630cd201d303b683c02c4ae5
# 1    630cd201d303b683c02c4aff
# 2    630cd201d303b683c02c4ad7
# 3    630cd201d303b683c02c4ade
# 4    630cd201d303b683c02c4adb
# ..                        ...
# 149  630cd201d303b683c02c4b03
# 150  630cd201d303b683c02c4b05
# 151  630cd201d303b683c02c4a79
# 152  630cd201d303b683c02c4a7c
# 153  630cd201d303b683c02c4ad3
#
#                                                                       postUrl  \
# 0    https://www.linkedin.com/feed/update/urn:li:activity:6969767021961961472
# 1    https://www.linkedin.com/feed/update/urn:li:activity:6969681287632568320
# 2    https://www.linkedin.com/feed/update/urn:li:activity:6969871628578996224
# 3    https://www.linkedin.com/feed/update/urn:li:activity:6969816728713277440
# 4    https://www.linkedin.com/feed/update/urn:li:activity:6969848445805215744
# ..                                                                        ...
# ...
