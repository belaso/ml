# %% [markdown]
# <a href="https://colab.research.google.com/github/belaso/ml/blob/master/Habeck.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install "pymongo[srv]"
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pymongo[srv] in /usr/local/lib/python3.7/dist-packages (4.2.0)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from pymongo[srv]) (2.2.1)

# %%
import pandas as pd
from pymongo import MongoClient
client = MongoClient("mongodb+srv://ml:Sokrates01@cluster0.tpudyxt.mongodb.net/?retryWrites=true&w=majority")
db = client["test"]
cursor = db["habeck"].find({}, projection = {'postUrl':1, 'postDate':1, 'textContent':1, 'likeCount':1, 'commentCount':1}, sort =[('likeCount', -1), ('commentCount', -1)])
df =  pd.DataFrame(list(cursor))

# %%
df
# Out:
#                           _id  \
# 0    630c897f5b23b6a749fd14d0
# 1    630c897f5b23b6a749fd14b7
# 2    630c897f5b23b6a749fd1456
# 3    630c897f5b23b6a749fd1471
# 4    630c897f5b23b6a749fd14e3
# ..                        ...
# 212  630c897f5b23b6a749fd1442
# 213  630c897f5b23b6a749fd1480
# 214  630c897f5b23b6a749fd1499
# 215  630c897f5b23b6a749fd14c2
# 216  630c897f5b23b6a749fd14d9
#
#                                                postUrl postDate  \
# 0    https://www.linkedin.com/feed/update/urn:li:ac...   2 Tage
# 1    https://www.linkedin.com/feed/update/urn:li:ac...    1 Tag
# 2    https://www.linkedin.com/feed/update/urn:li:ac...  11 Std.
# 3    https://www.linkedin.com/feed/update/urn:li:ac...  16 Std.
# 4    https://www.linkedin.com/feed/update/urn:li:ac...   2 Tage
# ..                                                 ...      ...
# 212  https://www.linkedin.com/feed/update/urn:li:ac...   2 Std.
# 213  https://www.linkedin.com/feed/update/urn:li:ac...  21 Std.
# 214  https://www.linkedin.com/feed/update/urn:li:ac...    1 Tag
# 215  https://www.linkedin.com/feed/update/urn:li:ac...    1 Tag
# 216  https://www.linkedin.com/feed/update/urn:li:ac...   2 Tage
#
#                                            textContent  likeCount  \
# 0    So, here's the German Energiewende, in a nutsh...      158.0
# 1    Einen schönen guten Tag aus München!\nWerter H...       73.0
# 2    Ikväll frågades Nooshi Dadgostar ut i SVT1 och...       64.0
# 3    Si è parlato anche di gas naturale liquefatto ...       61.0
# 4    Jetzt sollte es dem letzten Klar sein, dass Ha...       42.0
# ..                                                 ...        ...
# 212  #Energie- und #Strompreise werden uns auch in ...        NaN
# 213  Mit einer Reform könnten Strom- und Gaspreis e...        NaN
# 214  A U F W A C H E N !!\n\nChristian Lindner, FDP...        NaN
# 215                  #habeck #verachtung #deutschland         NaN
# 216                                                           NaN
#
#      commentCount
# 0            24.0
# 1            17.0
# 2            10.0
# 3             2.0
# 4             6.0
# ..            ...
# 212           NaN
# 213           NaN
# 214           NaN
# 215           NaN
# 216           NaN
#
# [217 rows x 6 columns]
